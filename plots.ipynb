# %%
import numpy as np
import matplotlib.pyplot as plt
from ising2D import Ising2D

# %matplotlib inline

# %%
#static parameters for all systems

N     = 25
J     = 1
T     = 10        #this is just a dummy temperature value to initialize
steps = 2500

#function used to compute analytical predictions

def mag(T):
    z = np.exp(-2/T)
    if T > 2.269185:
        return 0
    else:
        return (((1 + z**2)**(.25))*(1-6*z**2 + z**4)**(.125))/np.sqrt((1-z**2))

# %% [markdown]
# # Initially aligned spins, no external field

# %%
H = 0
Ising = Ising2D('aligned',J,N,T,H,steps)

# %%
E,M,temps = Ising.changingTemp('heat')

mags = []
for i in np.nditer(temps):
    mags.append(mag(i))

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M, color='b', label='Simulation')
plt.plot(temps, mags, label='Analytical')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.axis('tight')
plt.legend()

plt.show()

# %% [markdown]
# # Initially aligned spins, with external field

# %% [markdown]
# ## Positive Field

# %%
H2 = 2
Ising2 = Ising2D('aligned',J,N,T,H2,steps)

# %%
E2,M2,temps = Ising2.changingTemp('heat')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E2)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M2, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.axis('tight')

plt.show()

# %% [markdown]
# ## Negative Field (Weak)

# %%
H3 = -0.25 
Ising3 = Ising2D('aligned',J,N,T,H3,steps)

# %%
E3,M3,temps = Ising3.changingTemp('heat')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E3)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M3, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.axis('tight')

plt.show()

# %% [markdown]
# ## Negative Field (Strong)

# %%
H7 = -5 
Ising7 = Ising2D('aligned',J,N,T,H7,steps)

# %%
E7,M7,temps = Ising7.changingTemp('heat')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps[1:], np.array(E7)[1:]/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps[1:], M7[1:], color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.axis('tight')

plt.show()

# %% [markdown]
# # Random initial spins, no field

# %%
H4 = 0
Ising4 = Ising2D('random',J,N,T,H4,steps)

# %%
E4,M4,temps = Ising4.changingTemp('cool')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E4)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M4, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.axis('tight')

plt.show()

# %% [markdown]
# # Random initial spins, with external field

# %% [markdown]
# ## Positive Field

# %%
H5 = 1
Ising5 = Ising2D('random',J,N,T,H5,steps)

# %%
E5,M5,temps = Ising5.changingTemp('cool')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E5)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M5, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plt.show()

# %% [markdown]
# ## Negative Field

# %%
H6 = -1
Ising6 = Ising2D('random',J,N,T,H6,steps)

# %%
E6,M6,temps = Ising6.changingTemp('cool')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E6)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M6, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plt.show()
