# %% [markdown]
# # 2D-Ising Model

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from ising2D import Ising2D

# %%
# Define the core parameters for the system we want to test.

N     = 25      # Number of lattice points/dipoles.
J     = 1       # Exchange energy.
T     = 10      # Set an initial temperature so the program can start.
steps = 2500    # Monte Carlo steps.

# %% [markdown]
# # Spins are initially aligned with no external magnetic field

# %%
# Set external magnetic field value to zero and initial state to all spins aligned.
H1 = 0
Ising = Ising2D('aligned',J,N,T,H1,steps)

# Pick the temperature method; in this case we start from zero and heat the system up.
E,M,temps = Ising.changingTemp('heat')

# Compute the analytical result for comparison.
def mag(T):
    z = np.exp(-2/T)
    if T > 2.269185:
        return 0
    else:
        return (((1 + z**2)**(.25))*(1-6*z**2 + z**4)**(.125))/np.sqrt((1-z**2))
mags = []
for i in np.nditer(temps):
    mags.append(mag(i))

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M, color='b', label='Simulation')
plt.plot(temps, mags, label='Analytical')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.axis('tight')
plt.legend()

plt.show()

# %% [markdown]
# # Spins are initially aligned with non-zero external magnetic field

# %% [markdown]
# ## Positive Field

# %%
# Set external magnetic field value to two and initial state to all spins aligned.
H2 = 2
Ising2 = Ising2D('aligned',J,N,T,H2,steps)

# Pick the temperature method; in this case we start from zero and heat the system up.
E2,M2,temps = Ising2.changingTemp('heat')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E2)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M2, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.axis('tight')

plt.show()

# %% [markdown]
# ## Negative Field (Weak)

# %%
# Set external magnetic field value to -0.25 and initial state to all spins aligned.
H3 = -0.25 
Ising3 = Ising2D('aligned',J,N,T,H3,steps)

# Pick the temperature method; in this case we start from zero and heat the system up.
E3,M3,temps = Ising3.changingTemp('heat')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E3)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M3, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.axis('tight')

plt.show()

# %% [markdown]
# ## Negative Field (Strong)

# %%
# Set external magnetic field value to -5 and initial state to all spins aligned.
H4 = -5 
Ising4 = Ising2D('aligned',J,N,T,H4,steps)

# Pick the temperature method; in this case we start from zero and heat the system up.
E4,M4,temps = Ising4.changingTemp('heat')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps[1:], np.array(E4)[1:]/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps[1:], M4[1:], color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.axis('tight')

plt.show()

# %% [markdown]
# # Spins are initially random with zero external magnetic field

# %%
# Set external magnetic field value to zero and initial state to all spins randomly configured.
H5 = 0
Ising5 = Ising2D('random',J,N,T,H5,steps)

# Pick the temperature method; in this case we start from ten and cool the system down.
E5,M5,temps = Ising5.changingTemp('cool')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E5)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M5, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plt.show()

# %% [markdown]
# # Spins are initially random with non-zero external magnetic field

# %% [markdown]
# ## Positive Field

# %%
# Set external magnetic field value to 1 and initial state to all spins randomly configured.
H6 = 1
Ising6 = Ising2D('random',J,N,T,H6,steps)

# Pick the temperature method; in this case we start from ten and cool the system down.
E6,M6,temps = Ising6.changingTemp('cool')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E6)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M6, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plt.show()

# %% [markdown]
# ## Negative Field

# %%
# Set external magnetic field value to -1 and initial state to all spins randomly configured.
H7 = -1
Ising7 = Ising2D('random',J,N,T,H7,steps)

# Pick the temperature method; in this case we start from ten and cool the system down.
E7,M7,temps = Ising7.changingTemp('cool')

# %%
plot = plt.figure(figsize=(16,12))

plot.add_subplot(211);
plt.scatter(temps, np.array(E7)/(N*N), color = 'r')
plt.title('Energy Per Spin vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Energy per spin (J)', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plot.add_subplot(212);
plt.scatter(temps, M7, color='b')
plt.title('Magnetization Fraction vs. Temperature', fontsize=20)
plt.xlabel(r'T (Kelvin)', fontsize=15)
plt.ylabel('Magnetization Fraction', fontsize=15)
plt.gca().invert_xaxis()
plt.axis('tight')

plt.show()
